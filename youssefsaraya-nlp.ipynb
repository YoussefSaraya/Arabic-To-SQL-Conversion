# %%
# STEP 0: Install required libraries
# !pip install transformers datasets stanza nltk --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.6 MB/s eta 0:00:00 0:00:01

# %%
# STEP 1: Import libraries
import os
import json
import pandas as pd
import numpy as np
import sqlite3
import nltk
import stanza
import torch
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from transformers import MT5Tokenizer, MT5ForConditionalGeneration, AdamW
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from tqdm import tqdm

nltk.download('punkt')
stanza.download('ar')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# Downloading https://huggingface.co/stanfordnlp/stanza-ar/resolve/v1.10.0/models/default.zip:   0%|          | …

# %%
import json

rows = []
with open("/kaggle/input/txttosql-nlp/AR_spider.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        rows.append(json.loads(line.strip()))

import pandas as pd
df = pd.DataFrame(rows)

# %%
print(df.head())
# Out:
#                                             question  \
# 0  How many heads of the departments are older th...
# 1  List the name, born state and age of the heads...
# 2  List the creation year, name and budget of eac...
# 3  What are the maximum and minimum budget of the...
# 4  What is the average number of employees of the...
#
#                                                query  \
# 0         SELECT count(*) FROM head WHERE age  >  56
# 1  SELECT name ,  born_state ,  age FROM head ORD...
# 2  SELECT creation ,  name ,  budget_in_billions ...
# 3  SELECT max(budget_in_billions) ,  min(budget_i...
# 4  SELECT avg(num_employees) FROM department WHER...
#
#                                               arabic                  db_id
# 0  كم عدد رؤساء الأقسام الذين تزيد أعمارهم عن 56 ...  department_management
# 1  اعرض قائمة بأسماء رؤساء الأقسام، مكان ميلادهم،...  department_management
# 2  اعرض قائمة بسنوات الإنشاء، وأسماء وميزانيات كل...  department_management
# 3                  ما هي أقصى وأدنى ميزانية للأقسام؟  department_management
# 4  ما هو المتوسط ​​لعدد الموظفين في الأقسام الذين...  department_management

# %%
# STEP 3: Preprocess Arabic text
nlp = stanza.Pipeline('ar', processors='tokenize,lemma')
stopwords = {'في', 'من', 'على', 'و', 'عن', 'إلى', 'مع', 'التي', 'الذي', 'هذا', 'أن', 'ما', 'هو', 'هي'}

def preprocess_arabic(text):
    doc = nlp(text)
    return ' '.join([w.lemma for s in doc.sentences for w in s.words if w.lemma not in stopwords])
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …

# %%
# Apply preprocessing + task prefix
df['input_text'] = df['arabic'].apply(lambda x: "ترجم إلى SQL: " + preprocess_arabic(x))
df['target_text'] = df['query']

# %%
# STEP 4: Split data
X = df['input_text'].tolist()
y = df['target_text'].tolist()
db_ids = df['db_id'].tolist()

X_train, X_temp, y_train, y_temp, db_train, db_temp = train_test_split(X, y, db_ids, test_size=0.3, random_state=42)
X_val, X_test, y_val, y_test, db_val, db_test = train_test_split(X_temp, y_temp, db_temp, test_size=0.5, random_state=42)

# %%
# STEP 5: Load model and tokenizer
model_name = "google/mt5-small"
tokenizer = MT5Tokenizer.from_pretrained(model_name)
model = MT5ForConditionalGeneration.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/82.0 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/553 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# pytorch_model.bin:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
# STEP 6: Tokenize
max_len = 128

def tokenize_data(X, y):
    encodings = tokenizer(X, padding=True, truncation=True, max_length=max_len, return_tensors="pt")
    targets = tokenizer(y, padding=True, truncation=True, max_length=max_len, return_tensors="pt")
    return encodings, targets

train_enc, train_tar = tokenize_data(X_train, y_train)
val_enc, val_tar = tokenize_data(X_val, y_val)

# %%
# STEP 7: Create DataLoaders
dev = torch.device("cuda" if torch.cuda.is_available() else "cpu")

train_dataset = TensorDataset(train_enc['input_ids'], train_enc['attention_mask'], train_tar['input_ids'])
val_dataset = TensorDataset(val_enc['input_ids'], val_enc['attention_mask'], val_tar['input_ids'])

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=4)

# %%
# STEP 8: Training
model.to(dev)
optimizer = AdamW(model.parameters(), lr=5e-5)
num_epochs = 8

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}")

    for batch in loop:
        input_ids, attention_mask, labels = [b.to(dev) for b in batch]
        labels[labels == tokenizer.pad_token_id] = -100

        outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        loss.backward()

        optimizer.step()
        optimizer.zero_grad()

        total_loss += loss.item()
        loop.set_postfix(loss=loss.item())
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch 1/8:   0%|          | 0/1120 [00:00<?, ?it/s]Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# Epoch 1/8: 100%|██████████| 1120/1120 [05:39<00:00,  3.29it/s, loss=4.32]
# Epoch 2/8: 100%|██████████| 1120/1120 [05:40<00:00,  3.29it/s, loss=3.51]
# Epoch 3/8: 100%|██████████| 1120/1120 [05:40<00:00,  3.28it/s, loss=3.34]
# Epoch 4/8: 100%|██████████| 1120/1120 [05:40<00:00,  3.29it/s, loss=2.9]
# Epoch 5/8: 100%|██████████| 1120/1120 [05:40<00:00,  3.29it/s, loss=1.27]
# Epoch 6/8: 100%|██████████| 1120/1120 [05:40<00:00,  3.29it/s, loss=2.09]
# Epoch 7/8: 100%|██████████| 1120/1120 [05:40<00:00,  3.29it/s, loss=2.63]
# Epoch 8/8: 100%|██████████| 1120/1120 [05:40<00:00,  3.28it/s, loss=2.27]

# %%
# STEP 9: Inference function
def generate_sql(question, table_names=None):
    model.eval()
    schema_part = f" ### الجداول: {', '.join(table_names)}" if table_names else ""
    prompt = "ترجم إلى SQL: " + preprocess_arabic(question) + schema_part
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, padding=True, max_length=max_len).to(dev)
    outputs = model.generate(**inputs, max_length=max_len, num_beams=4, early_stopping=True)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
# STEP 10: Build test_data list from X_test, y_test, db_test
test_data = []
for i in range(len(X_test)):
    row = df[df['input_text'] == X_test[i]].iloc[0]
    test_data.append({
        "question": row['arabic'],
        "query": y_test[i],
        "db_id": db_test[i],
        "table_names": row.get('table_names', [])
    })

# %%
# STEP 11: Evaluation using test_data format
smoothie = SmoothingFunction().method4
def execute_sql(db_id, sql_query):
    db_path = f"/kaggle/input/txttosql-nlp/database/{db_id}.sqlite"
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()
        cursor.execute(sql_query)
        result = cursor.fetchall()
        conn.close()
        return result
    except Exception as e:
        return f"Error: {str(e)}"

# Metrics tracking
exact_match_count = 0
execution_match_count = 0
bleu_scores = []
total_samples = len(test_data)

for idx, entry in enumerate(test_data[:50]):
    print(f"Sample {idx + 1}/{min(50, len(test_data))}")

    print(f"🔸 Question: {entry['question']}")
    print(f"📁 DB: {entry['db_id']}.sqlite")
    print(f"✅ Ground Truth SQL: {entry['query']}")
    arabic_question = entry["question"]
    correct_sql = sqlparse.format(entry["query"], reindent=True, keyword_case="upper")
    db_id = entry["db_id"]

    predicted_sql = generate_sql(arabic_question, entry.get("table_names", [])).strip()
    print(f"✨ Predicted SQL: {predicted_sql}")

    # Exact Match Accuracy
    if predicted_sql.strip() == correct_sql.strip():
        exact_match_count += 1

    # Execution Accuracy
    correct_result = execute_sql(db_id, correct_sql)
    predicted_result = execute_sql(db_id, predicted_sql)
    if correct_result == predicted_result:
        print("✅ SQL execution matched.")
        execution_match_count += 1
    else:
        print("❌ Execution mismatch or error occurred.")
        print("Correct Result:", correct_result)
        print("Predicted Result:", predicted_result)

    # BLEU Score (SQL as tokenized words)
    reference_tokens = correct_sql.split()
    predicted_tokens = predicted_sql.split()
    bleu_scores.append(sentence_bleu([reference_tokens], predicted_tokens, smoothing_function=smoothie))

# Final Metrics
exact_match_acc = exact_match_count / total_samples
execution_acc = execution_match_count / total_samples
average_bleu = sum(bleu_scores) / total_samples

# Display Results
print(f"✅ Exact Match Accuracy: {exact_match_acc:.4f}")
print(f"✅ Execution Accuracy: {execution_acc:.4f}")
print(f"✅ Average BLEU Score: {average_bleu:.4f}")
# Out:
# Sample 1/50
# 🔸 Question: ما هي أوضاع اللاعبين مع متوسط عدد النقاط المُسجَّلة من قبل اللاعبين في تلك الوضع أكبر من 20؟
# 📁 DB: sports_competition.sqlite
# ✅ Ground Truth SQL: SELECT POSITION ,  avg(Points) FROM player GROUP BY POSITION
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name FROM exhibition AS T1 JOIN film AS T2 ON T1.film_id = T2.film_id WHERE T1.film_id = T2.film_id GROUP BY T1.film_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 2/50
# 🔸 Question: [Question] أعط المدينة التي يعيش فيها الطالب الذي يحمل اسم العائلة Kim.
# 📁 DB: allergy_1.sqlite
# ✅ Ground Truth SQL: SELECT city_code FROM Student WHERE LName  =  "Kim"
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 3/50
# 🔸 Question: فرز قائمة جميع الأسماء الأولى والألقاب للكتّاب ترتيباً أبجدياً حسب الألقاب.
# 📁 DB: icfp_1.sqlite
# ✅ Ground Truth SQL: SELECT fname ,  lname FROM authors ORDER BY lname
# ✨ Predicted SQL: SELECT count(*) FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 4/50
# 🔸 Question: ما هي أسماء جميع الأغاني التي يكون ألبومها تحت علامة "Universal Music Group"؟
# 📁 DB: music_2.sqlite
# ✅ Ground Truth SQL: SELECT T3.title FROM albums AS T1 JOIN tracklists AS T2 ON T1.aid  =  T2.albumid JOIN songs AS T3 ON T2.songid  =  T3.songid WHERE t1.label  =  "Universal Music Group"
# ✨ Predicted SQL: SELECT T1.name FROM film AS T1 JOIN film AS T2 ON T1.film_id = T2.film_id WHERE T1.film_id = T2.film_id GROUP BY T1.film_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 5/50
# 🔸 Question: ما هو تاريخ الطلب لكل حجز؟
# 📁 DB: cre_Drama_Workshop_Groups.sqlite
# ✅ Ground Truth SQL: SELECT Order_Date FROM BOOKINGS
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name FROM
# ✅ SQL execution matched.
# Sample 6/50
# 🔸 Question: "أي منتج تم طلبه الأكثر عددًا من المرات؟"
# 📁 DB: customers_and_addresses.sqlite
# ✅ Ground Truth SQL: SELECT sum(t2.order_quantity) FROM customer_orders AS t1 JOIN order_items AS t2 ON t1.order_id  =  t2.order_id WHERE t1.order_date  <  "2018-03-17 07:13:53"
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 7/50
# 🔸 Question: كم عدد المدرسين المختلفين الذين قاموا بتدريس بعض الدورات؟
# 📁 DB: college_2.sqlite
# ✅ Ground Truth SQL: SELECT COUNT (DISTINCT id) FROM teaches
# ✨ Predicted SQL: SELECT count(*) FROM employees
# ✅ SQL execution matched.
# Sample 8/50
# 🔸 Question: ما هو متوسط نقاط السناتش لبناة الأجسام؟
# 📁 DB: body_builder.sqlite
# ✅ Ground Truth SQL: SELECT avg(Snatch) FROM body_builder
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 9/50
# 🔸 Question: ما هي أسماء النواب بترتيب تنازلي حسب الأصوات؟
# 📁 DB: election_representative.sqlite
# ✅ Ground Truth SQL: SELECT T2.Name FROM election AS T1 JOIN representative AS T2 ON T1.Representative_ID  =  T2.Representative_ID ORDER BY votes DESC
# ✨ Predicted SQL: SELECT count(*) FROM player
# ✅ SQL execution matched.
# Sample 10/50
# 🔸 Question: أعط معرف المنتج ونوع المنتج للمنتج بأقل سعر.
# 📁 DB: department_store.sqlite
# ✅ Ground Truth SQL: SELECT product_id ,  product_type_code FROM products ORDER BY product_price LIMIT 1
# ✨ Predicted SQL: SELECT count(*) FROM customer WHERE customer_id = "customer_id GROUP BY customer_id ORDER BY customer_id
# ✅ SQL execution matched.
# Sample 11/50
# 🔸 Question: [Question] أظهر جميع معرف الطلاب الذين يمتلكون ما لا يقل عن حساسيةين.
# 📁 DB: allergy_1.sqlite
# ✅ Ground Truth SQL: SELECT StuID FROM Has_allergy GROUP BY StuID HAVING count(*)  >=  2
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 12/50
# 🔸 Question: العثور على الراتب الأدنى للأقسام التي يكون متوسط الراتب فيها أعلى من المتوسط العام لجميع المدرسين.
# 📁 DB: college_2.sqlite
# ✅ Ground Truth SQL: SELECT min(salary) ,  dept_name FROM instructor GROUP BY dept_name HAVING avg(salary)  >  (SELECT avg(salary) FROM instructor)
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.employee_id = T2.employee_id WHERE T1.employee_id = T2.employee_id GROUP BY T1.employee_id ORDER BY T1.employee_id DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 13/50
# 🔸 Question: ما هي المتوسط والحضور الأقصى لجميع الأحداث؟
# 📁 DB: news_report.sqlite
# ✅ Ground Truth SQL: SELECT Name FROM journalist WHERE journalist_ID NOT IN (SELECT journalist_ID FROM news_report)
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name FROM
# ✅ SQL execution matched.
# Sample 14/50
# 🔸 Question: [Question] ما هو الراتب واسم الموظف الذي يحمل أكبر عدد من الشهادات على الطائرات التي تتجاوز مسافتها 5000؟
# 📁 DB: flight_1.sqlite
# ✅ Ground Truth SQL: SELECT T1.name FROM Employee AS T1 JOIN Certificate AS T2 ON T1.eid  =  T2.eid JOIN Aircraft AS T3 ON T3.aid  =  T2.aid WHERE T3.distance  >  5000 GROUP BY T1.eid ORDER BY count(*) DESC LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id HAVING count(*) > 5000
# ✅ SQL execution matched.
# Sample 15/50
# 🔸 Question: ما هو متوسط نقاط الدرجات للطلاب الذين يحملون اسم العائلة Smith؟
# 📁 DB: college_3.sqlite
# ✅ Ground Truth SQL: SELECT avg(T2.gradepoint) FROM ENROLLED_IN AS T1 JOIN GRADECONVERSION AS T2 JOIN STUDENT AS T3 ON T1.Grade  =  T2.lettergrade AND T1.StuID  =  T3.StuID WHERE T3.LName  =  "Smith"
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 16/50
# 🔸 Question: ما هو معرِّف المريض الذي قام بالإقامة في الغرفة 111 بشكل أحدث؟
# 📁 DB: hospital_1.sqlite
# ✅ Ground Truth SQL: SELECT patient FROM stay WHERE room  =  111 ORDER BY staystart DESC LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 17/50
# 🔸 Question: ما هو متوسط وأدنى سعر للغرف في أنواع مختلفة من الديكور؟
# 📁 DB: inn_1.sqlite
# ✅ Ground Truth SQL: SELECT decor ,  count(*) FROM Rooms WHERE bedType = "King" GROUP BY decor;
# ✨ Predicted SQL: SELECT T1.product_name FROM products AS T1 JOIN products AS T2 ON T1.product_id = T2.product_id WHERE T1.product_id = T2.product_id GROUP BY T1.product_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 18/50
# 🔸 Question: كم عدد الأندية؟
# 📁 DB: college_1.sqlite
# ✅ Ground Truth SQL: SELECT T1.stu_fname FROM student AS T1 JOIN enroll AS T2 ON T1.stu_num  =  T2.stu_num JOIN CLASS AS T3 ON T2.class_code  =  T3.class_code WHERE T3.crs_code  =  'ACCT-211' AND T1.stu_lname LIKE 'S%'
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name FROM authors AS T1 JOIN authors AS T2 ON T1.name = T2.name GROUP BY T1.name
# ✅ SQL execution matched.
# Sample 19/50
# 🔸 Question: أعطِ المدن الأصلية التي يأتي منها جمبازان على الأقل.
# 📁 DB: gymnast.sqlite
# ✅ Ground Truth SQL: SELECT T2.Hometown FROM gymnast AS T1 JOIN people AS T2 ON T1.Gymnast_ID  =  T2.People_ID GROUP BY T2.Hometown HAVING COUNT(*)  >=  2
# ✨ Predicted SQL: SELECT T1.name FROM Employees AS T1 JOIN Customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 20/50
# 🔸 Question: قائمة باسم وعدد المتابعين لكل مستخدم، وقم بفرز النتائج حسب عدد المتابعين بترتيب تنازلي.
# 📁 DB: twitter_1.sqlite
# ✅ Ground Truth SQL: SELECT name ,  followers FROM user_profiles ORDER BY followers DESC
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 21/50
# 🔸 Question: لكل موقع، كم عدد محطات الوقود الموجودة بترتيب؟
# 📁 DB: gas_company.sqlite
# ✅ Ground Truth SQL: SELECT LOCATION ,  count(*) FROM gas_station GROUP BY LOCATION ORDER BY count(*)
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 22/50
# 🔸 Question: كم لاعب مختلف تدرب لأكثر من 1000 ساعة؟
# 📁 DB: soccer_2.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM Player WHERE HS  >  1000
# ✨ Predicted SQL: SELECT count(*) FROM player WHERE age > 1000
# ✅ SQL execution matched.
# Sample 23/50
# 🔸 Question: ما هو عدد العناصر التي لم تتلقى أي مراجعة؟
# 📁 DB: epinions_1.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM item WHERE i_id NOT IN (SELECT i_id FROM review)
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id GROUP BY T1.staff_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 24/50
# 🔸 Question: أعط وصف اللون الأقل شيوعًا عبر المنتجات.
# 📁 DB: products_gen_characteristics.sqlite
# ✅ Ground Truth SQL: SELECT t2.color_description FROM products AS t1 JOIN ref_colors AS t2 ON t1.color_code  =  t2.color_code GROUP BY t2.color_description ORDER BY count(*) ASC LIMIT 1
# ✨ Predicted SQL: SELECT count(*) FROM products
# ✅ SQL execution matched.
# Sample 25/50
# 🔸 Question: ما هو اسم القسم الذي ينتمي إليه الطالب الذي يمتلك أقل معدل نقاط تراكمي؟
# 📁 DB: college_1.sqlite
# ✅ Ground Truth SQL: SELECT T2.dept_name FROM student AS T1 JOIN department AS T2 ON T1.dept_code  =  T2.dept_code ORDER BY stu_gpa LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id = T2.staff_id GROUP BY T1.staff_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 26/50
# 🔸 Question: عدد فروع البنك؟
# 📁 DB: loan_1.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM bank
# ✨ Predicted SQL: SELECT count(*) FROM products
# ✅ SQL execution matched.
# Sample 27/50
# 🔸 Question: [Translation] ما هي أرقام تعريفية الطلاب الذين سجلوا في الدورة 301 مؤخرًا؟
# 📁 DB: student_assessment.sqlite
# ✅ Ground Truth SQL: SELECT student_id FROM student_course_attendance WHERE course_id = 301 ORDER BY date_of_attendance DESC LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 28/50
# 🔸 Question: كم عدد المدن المختلفة التي يوجد فيها البنوك؟
# 📁 DB: loan_1.sqlite
# ✅ Ground Truth SQL: SELECT state ,  acc_type ,  credit_score FROM customer WHERE no_of_loans  =  0
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.employeeid = T2.employeeid WHERE T1.employeeid = T2.employeeid WHERE T1.employeeid = T2.employeeid WHERE T1.employeeid = T2.employeeid
# ✅ SQL execution matched.
# Sample 29/50
# 🔸 Question: [Question] ما هي أسماء الإنزيمات في الدواء المسمى 'Amisulpride' التي يمكن أن تعمل كـ 'مثبط'؟
# 📁 DB: medicine_enzyme_interaction.sqlite
# ✅ Ground Truth SQL: SELECT T1.name FROM enzyme AS T1 JOIN medicine_enzyme_interaction AS T2 ON T1.id  =  T2.enzyme_id JOIN medicine AS T3 ON T2.medicine_id  =  T3.id WHERE T3.name  =  'Amisulpride' AND T2.interaction_type  =  'inhibitor'
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.id = T2.id WHERE T1.id = T2.id GROUP BY T1.id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 30/50
# 🔸 Question: كم عدد المتاجر التي يقع مقرها في كل مدينة؟
# 📁 DB: store_product.sqlite
# ✅ Ground Truth SQL: SELECT t3.headquartered_city ,  count(*) FROM store AS t1 JOIN store_district AS t2 ON t1.store_id  =  t2.store_id JOIN district AS t3 ON t2.district_id  =  t3.district_id GROUP BY t3.headquartered_city
# ✨ Predicted SQL: SELECT count(*) FROM customer WHERE customer_id = "SELECT customer_id GROUP BY customer_id ORDER BY customer_id DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 31/50
# 🔸 Question: ابحث عن الاسم، التسجيل في الكليات التي يكون حجمها أكبر من 10000 والموقع في ولاية لويزيانا.
# 📁 DB: soccer_2.sqlite
# ✅ Ground Truth SQL: SELECT DISTINCT pName FROM Player WHERE pName LIKE '%a%'
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 32/50
# 🔸 Question: ما هي مواقع جميع محطات الوقود مرتبة حسب سنة الافتتاح؟
# 📁 DB: gas_company.sqlite
# ✅ Ground Truth SQL: SELECT LOCATION FROM gas_station ORDER BY open_year
# ✨ Predicted SQL: SELECT count(*) FROM products WHERE product_type_code = "F"
# ✅ SQL execution matched.
# Sample 33/50
# 🔸 Question: أي عميل قام بعملية دفع واحدة على الأقل قد أنفق أقل مبلغ؟ قم بتقديم الاسم الأول والاسم الأخير، والمعرف.
# 📁 DB: sakila_1.sqlite
# ✅ Ground Truth SQL: SELECT sum(amount) FROM payment
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 34/50
# 🔸 Question: [Question] قائمة اسم نموذج الأجهزة واسم الشركة للهاتف الذي يكون نوع وضع الشاشة الخاص به "الرسومات".
# 📁 DB: phone_1.sqlite
# ✅ Ground Truth SQL: SELECT T2.Hardware_Model_name ,  T2.Company_name FROM screen_mode AS T1 JOIN phone AS T2 ON T1.Graphics_mode = T2.screen_mode WHERE T1.Type  =  "Graphics";
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 35/50
# 🔸 Question: أظهر هويات جميع الطلاب الذكور الذين لا يلعبون كرة القدم.
# 📁 DB: game_1.sqlite
# ✅ Ground Truth SQL: SELECT StuID FROM Student WHERE sex  =  'F' INTERSECT SELECT StuID FROM Sportsinfo WHERE sportname  =  "Football"
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id = T2.staff_id GROUP BY T1.staff_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 36/50
# 🔸 Question: كم عدد ألعاب الفيديو التي لديك؟
# 📁 DB: game_1.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM Video_games
# ✨ Predicted SQL: SELECT T1.name FROM film AS T1 JOIN film AS T2 ON T1.film_id = T2.film_id WHERE T1.film_id = T2.film_id
# ✅ SQL execution matched.
# Sample 37/50
# 🔸 Question: "ابحث عن رمز قناة الاتصال الذي تم استخدامه من قبل العميل بالاسم 'Tillman Ernser'."
# 📁 DB: customers_and_addresses.sqlite
# ✅ Ground Truth SQL: SELECT channel_code FROM customer_contact_channels GROUP BY channel_code HAVING count(customer_id)  <  5
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name FROM
# ✅ SQL execution matched.
# Sample 38/50
# 🔸 Question: عرض جميع أسماء المتاجر لمجموعات ورش العمل المسرحية.
# 📁 DB: cre_Drama_Workshop_Groups.sqlite
# ✅ Ground Truth SQL: SELECT Customer_Phone ,  Customer_Email_Address FROM CUSTOMERS WHERE Customer_Name  =  "Harold"
# ✨ Predicted SQL: SELECT T1.name FROM manufacturers AS T1 JOIN manufacturers AS T2 ON T1.product_id = T2.product_id WHERE T1.product_id = T2.product_id GROUP BY T1.product_id ORDER BY T1.product_id DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 39/50
# 🔸 Question: كم عدد الأعضاء؟
# 📁 DB: network_2.sqlite
# ✅ Ground Truth SQL: SELECT DISTINCT T4.name FROM PersonFriend AS T1 JOIN Person AS T2 ON T1.name  =  T2.name JOIN PersonFriend AS T3 ON T1.friend  =  T3.name JOIN PersonFriend AS T4 ON T3.friend  =  T4.name WHERE T2.name  =  'Alice' AND T4.name != 'Alice'
# ✨ Predicted SQL: SELECT count(*) FROM player
# ✅ SQL execution matched.
# Sample 40/50
# 🔸 Question: ما هي جميع المعلومات حول ملاحظات التقييم مرتبة حسب التاريخ بترتيب تصاعدي؟
# 📁 DB: behavior_monitoring.sqlite
# ✅ Ground Truth SQL: SELECT first_name FROM Teachers WHERE email_address LIKE '%man%'
# ✨ Predicted SQL: SELECT count(*) FROM exhibition WHERE exhibition_id = 'Spring'
# ✅ SQL execution matched.
# Sample 41/50
# 🔸 Question: [Question] أظهر معرف الطالب لجميع الطلاب الذكور.
# 📁 DB: allergy_1.sqlite
# ✅ Ground Truth SQL: SELECT StuID FROM Student WHERE Sex  =  'M'
# ✨ Predicted SQL: SELECT T1.name FROM Employees AS T1 JOIN Customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id = T2.customer_id GROUP BY T1.customer_id
# ✅ SQL execution matched.
# Sample 42/50
# 🔸 Question: ما هو أعلى وأقل مبلغ للتسوية في السجل؟
# 📁 DB: insurance_fnol.sqlite
# ✅ Ground Truth SQL: SELECT max(settlement_amount) ,  min(settlement_amount) FROM settlements
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name FROM
# ✅ SQL execution matched.
# Sample 43/50
# 🔸 Question: ما هي جميع الموظفين بدون رقم قسم؟
# 📁 DB: hr_1.sqlite
# ✅ Ground Truth SQL: SELECT * FROM employees WHERE department_id  =  "null"
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name FROM authors AS T1 JOIN authors AS T2 ON T1.name = T2.name GROUP BY T1.name ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 44/50
# 🔸 Question: [Question] من هم اللاعبون من إندونيسيا؟
# 📁 DB: match_season.sqlite
# ✅ Ground Truth SQL: SELECT T2.Player FROM country AS T1 JOIN match_season AS T2 ON T1.Country_id  =  T2.Country WHERE T1.Country_name  =  "Indonesia"
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name FROM authors AS T1 JOIN authors AS T2 ON T1.name = T2.name GROUP BY T1.name ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 45/50
# 🔸 Question: أي مدرسة لديها أقل عدد من الأساتذة؟
# 📁 DB: college_1.sqlite
# ✅ Ground Truth SQL: SELECT T1.school_code FROM department AS T1 JOIN professor AS T2 ON T1.dept_code  =  T2.dept_code GROUP BY T1.school_code ORDER BY count(*) LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 46/50
# 🔸 Question: "في شهر فبراير، أي مدينة تسجل أعلى درجة حرارة؟"
# 📁 DB: city_record.sqlite
# ✅ Ground Truth SQL: SELECT T1.city FROM city AS T1 JOIN temperature AS T2 ON T1.city_id  =  T2.city_id ORDER BY T2.Feb DESC LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 47/50
# 🔸 Question: ما هو اسم والمتوسط لمعدل النجاح للقسم الذي لديه أعلى متوسط لمعدل النجاح؟
# 📁 DB: college_1.sqlite
# ✅ Ground Truth SQL: SELECT max(stu_gpa) ,  avg(stu_gpa) ,  min(stu_gpa) ,  dept_code FROM student GROUP BY dept_code
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 48/50
# 🔸 Question: اعرض جميع أسماء الكنائس التي استضافت حفل زفاف على الأقل.
# 📁 DB: wedding.sqlite
# ✅ Ground Truth SQL: SELECT T1.name FROM church AS T1 JOIN wedding AS T2 ON T1.church_id  =  T2.church_id GROUP BY T1.church_id HAVING count(*)  >=  2
# ✨ Predicted SQL: SELECT T1.name FROM exhibition AS T1 JOIN exhibition AS T2 ON T1.exhibition_id = T2.exhibition_id WHERE T1.exhibition_id = T2.exhibition_id WHERE T1.exhibition_id = T2.exhibition_id = T2.exhibition_id WHERE T1.exhibition_id = T2.exhibition_id = T2.exhibition_id WHERE T1.exhibition_id = T2.exhibition_id = T2.exhibition_id WHERE T1.exhibition_id = T2.exhibition_id = T2.
# ✅ SQL execution matched.
# Sample 49/50
# 🔸 Question: أي رمز حالة هو الأكثر شيوعًا بين جميع الحجوزات؟
# 📁 DB: cre_Drama_Workshop_Groups.sqlite
# ✅ Ground Truth SQL: SELECT Status_Code FROM BOOKINGS GROUP BY Status_Code ORDER BY count(*) DESC LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM Employees AS T1 JOIN Customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 50/50
# 🔸 Question: بالنسبة لكل منتج يواجه مشاكل، قم بعرض عدد المشاكل ومعرّف المنتج.
# 📁 DB: tracking_software_problems.sqlite
# ✅ Ground Truth SQL: SELECT count(*) ,  T2.product_id FROM problems AS T1 JOIN product AS T2 ON T1.product_id = T2.product_id GROUP BY T2.product_id
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# ✅ Exact Match Accuracy: 0.0000
# ✅ Execution Accuracy: 0.0521
# ✅ Average BLEU Score: 0.0096

# %%
# STEP 11: Evaluation using test_data format
smoothie = SmoothingFunction().method4
def execute_sql(db_id, sql_query):
    db_path = f"/kaggle/input/txttosql-nlp/database/{db_id}.sqlite"
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()
        cursor.execute(sql_query)
        result = cursor.fetchall()
        conn.close()
        return result
    except Exception as e:
        return f"Error: {str(e)}"

# Metrics tracking
exact_match_count = 0
execution_match_count = 0
bleu_scores = []
total_samples = len(test_data)

for idx, entry in enumerate(test_data):
    print(f"Sample {idx + 1}/{len(test_data)}")

    print(f"🔸 Question: {entry['question']}")
    print(f"📁 DB: {entry['db_id']}.sqlite")
    print(f"✅ Ground Truth SQL: {entry['query']}")
    arabic_question = entry["question"]
    correct_sql = sqlparse.format(entry["query"], reindent=True, keyword_case="upper")
    db_id = entry["db_id"]

    predicted_sql = generate_sql(arabic_question, entry.get("table_names", [])).strip()
    print(f"✨ Predicted SQL: {predicted_sql}")

    # Exact Match Accuracy
    if predicted_sql.strip() == correct_sql.strip():
        exact_match_count += 1

    # Execution Accuracy
    correct_result = execute_sql(db_id, correct_sql)
    predicted_result = execute_sql(db_id, predicted_sql)
    if correct_result == predicted_result:
        print("✅ SQL execution matched.")
        execution_match_count += 1
    else:
        print("❌ Execution mismatch or error occurred.")
        print("Correct Result:", correct_result)
        print("Predicted Result:", predicted_result)

    # BLEU Score (SQL as tokenized words)
    reference_tokens = correct_sql.split()
    predicted_tokens = predicted_sql.split()
    bleu_scores.append(sentence_bleu([reference_tokens], predicted_tokens, smoothing_function=smoothie))

# Final Metrics
exact_match_acc = exact_match_count / total_samples
execution_acc = execution_match_count / total_samples
average_bleu = sum(bleu_scores) / total_samples

# Display Results
print(f"✅ Exact Match Accuracy: {exact_match_acc:.4f}")
print(f"✅ Execution Accuracy: {execution_acc:.4f}")
print(f"✅ Average BLEU Score: {average_bleu:.4f}")
# Out:
# Sample 1/960
# 🔸 Question: ما هي أوضاع اللاعبين مع متوسط عدد النقاط المُسجَّلة من قبل اللاعبين في تلك الوضع أكبر من 20؟
# 📁 DB: sports_competition.sqlite
# ✅ Ground Truth SQL: SELECT POSITION ,  avg(Points) FROM player GROUP BY POSITION
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name FROM exhibition AS T1 JOIN film AS T2 ON T1.film_id = T2.film_id WHERE T1.film_id = T2.film_id GROUP BY T1.film_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 2/960
# 🔸 Question: [Question] أعط المدينة التي يعيش فيها الطالب الذي يحمل اسم العائلة Kim.
# 📁 DB: allergy_1.sqlite
# ✅ Ground Truth SQL: SELECT city_code FROM Student WHERE LName  =  "Kim"
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 3/960
# 🔸 Question: فرز قائمة جميع الأسماء الأولى والألقاب للكتّاب ترتيباً أبجدياً حسب الألقاب.
# 📁 DB: icfp_1.sqlite
# ✅ Ground Truth SQL: SELECT fname ,  lname FROM authors ORDER BY lname
# ✨ Predicted SQL: SELECT count(*) FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 4/960
# 🔸 Question: ما هي أسماء جميع الأغاني التي يكون ألبومها تحت علامة "Universal Music Group"؟
# 📁 DB: music_2.sqlite
# ✅ Ground Truth SQL: SELECT T3.title FROM albums AS T1 JOIN tracklists AS T2 ON T1.aid  =  T2.albumid JOIN songs AS T3 ON T2.songid  =  T3.songid WHERE t1.label  =  "Universal Music Group"
# ✨ Predicted SQL: SELECT T1.name FROM film AS T1 JOIN film AS T2 ON T1.film_id = T2.film_id WHERE T1.film_id = T2.film_id GROUP BY T1.film_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 5/960
# 🔸 Question: ما هو تاريخ الطلب لكل حجز؟
# 📁 DB: cre_Drama_Workshop_Groups.sqlite
# ✅ Ground Truth SQL: SELECT Order_Date FROM BOOKINGS
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name FROM
# ✅ SQL execution matched.
# Sample 6/960
# 🔸 Question: "أي منتج تم طلبه الأكثر عددًا من المرات؟"
# 📁 DB: customers_and_addresses.sqlite
# ✅ Ground Truth SQL: SELECT sum(t2.order_quantity) FROM customer_orders AS t1 JOIN order_items AS t2 ON t1.order_id  =  t2.order_id WHERE t1.order_date  <  "2018-03-17 07:13:53"
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 7/960
# 🔸 Question: كم عدد المدرسين المختلفين الذين قاموا بتدريس بعض الدورات؟
# 📁 DB: college_2.sqlite
# ✅ Ground Truth SQL: SELECT COUNT (DISTINCT id) FROM teaches
# ✨ Predicted SQL: SELECT count(*) FROM employees
# ✅ SQL execution matched.
# Sample 8/960
# 🔸 Question: ما هو متوسط نقاط السناتش لبناة الأجسام؟
# 📁 DB: body_builder.sqlite
# ✅ Ground Truth SQL: SELECT avg(Snatch) FROM body_builder
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 9/960
# 🔸 Question: ما هي أسماء النواب بترتيب تنازلي حسب الأصوات؟
# 📁 DB: election_representative.sqlite
# ✅ Ground Truth SQL: SELECT T2.Name FROM election AS T1 JOIN representative AS T2 ON T1.Representative_ID  =  T2.Representative_ID ORDER BY votes DESC
# ✨ Predicted SQL: SELECT count(*) FROM player
# ✅ SQL execution matched.
# Sample 10/960
# 🔸 Question: أعط معرف المنتج ونوع المنتج للمنتج بأقل سعر.
# 📁 DB: department_store.sqlite
# ✅ Ground Truth SQL: SELECT product_id ,  product_type_code FROM products ORDER BY product_price LIMIT 1
# ✨ Predicted SQL: SELECT count(*) FROM customer WHERE customer_id = "customer_id GROUP BY customer_id ORDER BY customer_id
# ✅ SQL execution matched.
# Sample 11/960
# 🔸 Question: [Question] أظهر جميع معرف الطلاب الذين يمتلكون ما لا يقل عن حساسيةين.
# 📁 DB: allergy_1.sqlite
# ✅ Ground Truth SQL: SELECT StuID FROM Has_allergy GROUP BY StuID HAVING count(*)  >=  2
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 12/960
# 🔸 Question: العثور على الراتب الأدنى للأقسام التي يكون متوسط الراتب فيها أعلى من المتوسط العام لجميع المدرسين.
# 📁 DB: college_2.sqlite
# ✅ Ground Truth SQL: SELECT min(salary) ,  dept_name FROM instructor GROUP BY dept_name HAVING avg(salary)  >  (SELECT avg(salary) FROM instructor)
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.employee_id = T2.employee_id WHERE T1.employee_id = T2.employee_id GROUP BY T1.employee_id ORDER BY T1.employee_id DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 13/960
# 🔸 Question: ما هي المتوسط والحضور الأقصى لجميع الأحداث؟
# 📁 DB: news_report.sqlite
# ✅ Ground Truth SQL: SELECT Name FROM journalist WHERE journalist_ID NOT IN (SELECT journalist_ID FROM news_report)
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name FROM
# ✅ SQL execution matched.
# Sample 14/960
# 🔸 Question: [Question] ما هو الراتب واسم الموظف الذي يحمل أكبر عدد من الشهادات على الطائرات التي تتجاوز مسافتها 5000؟
# 📁 DB: flight_1.sqlite
# ✅ Ground Truth SQL: SELECT T1.name FROM Employee AS T1 JOIN Certificate AS T2 ON T1.eid  =  T2.eid JOIN Aircraft AS T3 ON T3.aid  =  T2.aid WHERE T3.distance  >  5000 GROUP BY T1.eid ORDER BY count(*) DESC LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id HAVING count(*) > 5000
# ✅ SQL execution matched.
# Sample 15/960
# 🔸 Question: ما هو متوسط نقاط الدرجات للطلاب الذين يحملون اسم العائلة Smith؟
# 📁 DB: college_3.sqlite
# ✅ Ground Truth SQL: SELECT avg(T2.gradepoint) FROM ENROLLED_IN AS T1 JOIN GRADECONVERSION AS T2 JOIN STUDENT AS T3 ON T1.Grade  =  T2.lettergrade AND T1.StuID  =  T3.StuID WHERE T3.LName  =  "Smith"
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 16/960
# 🔸 Question: ما هو معرِّف المريض الذي قام بالإقامة في الغرفة 111 بشكل أحدث؟
# 📁 DB: hospital_1.sqlite
# ✅ Ground Truth SQL: SELECT patient FROM stay WHERE room  =  111 ORDER BY staystart DESC LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 17/960
# 🔸 Question: ما هو متوسط وأدنى سعر للغرف في أنواع مختلفة من الديكور؟
# 📁 DB: inn_1.sqlite
# ✅ Ground Truth SQL: SELECT decor ,  count(*) FROM Rooms WHERE bedType = "King" GROUP BY decor;
# ✨ Predicted SQL: SELECT T1.product_name FROM products AS T1 JOIN products AS T2 ON T1.product_id = T2.product_id WHERE T1.product_id = T2.product_id GROUP BY T1.product_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 18/960
# 🔸 Question: كم عدد الأندية؟
# 📁 DB: college_1.sqlite
# ✅ Ground Truth SQL: SELECT T1.stu_fname FROM student AS T1 JOIN enroll AS T2 ON T1.stu_num  =  T2.stu_num JOIN CLASS AS T3 ON T2.class_code  =  T3.class_code WHERE T3.crs_code  =  'ACCT-211' AND T1.stu_lname LIKE 'S%'
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name FROM authors AS T1 JOIN authors AS T2 ON T1.name = T2.name GROUP BY T1.name
# ✅ SQL execution matched.
# Sample 19/960
# 🔸 Question: أعطِ المدن الأصلية التي يأتي منها جمبازان على الأقل.
# 📁 DB: gymnast.sqlite
# ✅ Ground Truth SQL: SELECT T2.Hometown FROM gymnast AS T1 JOIN people AS T2 ON T1.Gymnast_ID  =  T2.People_ID GROUP BY T2.Hometown HAVING COUNT(*)  >=  2
# ✨ Predicted SQL: SELECT T1.name FROM Employees AS T1 JOIN Customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 20/960
# 🔸 Question: قائمة باسم وعدد المتابعين لكل مستخدم، وقم بفرز النتائج حسب عدد المتابعين بترتيب تنازلي.
# 📁 DB: twitter_1.sqlite
# ✅ Ground Truth SQL: SELECT name ,  followers FROM user_profiles ORDER BY followers DESC
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 21/960
# 🔸 Question: لكل موقع، كم عدد محطات الوقود الموجودة بترتيب؟
# 📁 DB: gas_company.sqlite
# ✅ Ground Truth SQL: SELECT LOCATION ,  count(*) FROM gas_station GROUP BY LOCATION ORDER BY count(*)
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 22/960
# 🔸 Question: كم لاعب مختلف تدرب لأكثر من 1000 ساعة؟
# 📁 DB: soccer_2.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM Player WHERE HS  >  1000
# ✨ Predicted SQL: SELECT count(*) FROM player WHERE age > 1000
# ✅ SQL execution matched.
# Sample 23/960
# 🔸 Question: ما هو عدد العناصر التي لم تتلقى أي مراجعة؟
# 📁 DB: epinions_1.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM item WHERE i_id NOT IN (SELECT i_id FROM review)
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id GROUP BY T1.staff_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 24/960
# 🔸 Question: أعط وصف اللون الأقل شيوعًا عبر المنتجات.
# 📁 DB: products_gen_characteristics.sqlite
# ✅ Ground Truth SQL: SELECT t2.color_description FROM products AS t1 JOIN ref_colors AS t2 ON t1.color_code  =  t2.color_code GROUP BY t2.color_description ORDER BY count(*) ASC LIMIT 1
# ✨ Predicted SQL: SELECT count(*) FROM products
# ✅ SQL execution matched.
# Sample 25/960
# 🔸 Question: ما هو اسم القسم الذي ينتمي إليه الطالب الذي يمتلك أقل معدل نقاط تراكمي؟
# 📁 DB: college_1.sqlite
# ✅ Ground Truth SQL: SELECT T2.dept_name FROM student AS T1 JOIN department AS T2 ON T1.dept_code  =  T2.dept_code ORDER BY stu_gpa LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id = T2.staff_id GROUP BY T1.staff_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 26/960
# 🔸 Question: عدد فروع البنك؟
# 📁 DB: loan_1.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM bank
# ✨ Predicted SQL: SELECT count(*) FROM products
# ✅ SQL execution matched.
# Sample 27/960
# 🔸 Question: [Translation] ما هي أرقام تعريفية الطلاب الذين سجلوا في الدورة 301 مؤخرًا؟
# 📁 DB: student_assessment.sqlite
# ✅ Ground Truth SQL: SELECT student_id FROM student_course_attendance WHERE course_id = 301 ORDER BY date_of_attendance DESC LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 28/960
# 🔸 Question: كم عدد المدن المختلفة التي يوجد فيها البنوك؟
# 📁 DB: loan_1.sqlite
# ✅ Ground Truth SQL: SELECT state ,  acc_type ,  credit_score FROM customer WHERE no_of_loans  =  0
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.employeeid = T2.employeeid WHERE T1.employeeid = T2.employeeid WHERE T1.employeeid = T2.employeeid WHERE T1.employeeid = T2.employeeid
# ✅ SQL execution matched.
# Sample 29/960
# 🔸 Question: [Question] ما هي أسماء الإنزيمات في الدواء المسمى 'Amisulpride' التي يمكن أن تعمل كـ 'مثبط'؟
# 📁 DB: medicine_enzyme_interaction.sqlite
# ✅ Ground Truth SQL: SELECT T1.name FROM enzyme AS T1 JOIN medicine_enzyme_interaction AS T2 ON T1.id  =  T2.enzyme_id JOIN medicine AS T3 ON T2.medicine_id  =  T3.id WHERE T3.name  =  'Amisulpride' AND T2.interaction_type  =  'inhibitor'
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.id = T2.id WHERE T1.id = T2.id GROUP BY T1.id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 30/960
# 🔸 Question: كم عدد المتاجر التي يقع مقرها في كل مدينة؟
# 📁 DB: store_product.sqlite
# ✅ Ground Truth SQL: SELECT t3.headquartered_city ,  count(*) FROM store AS t1 JOIN store_district AS t2 ON t1.store_id  =  t2.store_id JOIN district AS t3 ON t2.district_id  =  t3.district_id GROUP BY t3.headquartered_city
# ✨ Predicted SQL: SELECT count(*) FROM customer WHERE customer_id = "SELECT customer_id GROUP BY customer_id ORDER BY customer_id DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 31/960
# 🔸 Question: ابحث عن الاسم، التسجيل في الكليات التي يكون حجمها أكبر من 10000 والموقع في ولاية لويزيانا.
# 📁 DB: soccer_2.sqlite
# ✅ Ground Truth SQL: SELECT DISTINCT pName FROM Player WHERE pName LIKE '%a%'
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 32/960
# 🔸 Question: ما هي مواقع جميع محطات الوقود مرتبة حسب سنة الافتتاح؟
# 📁 DB: gas_company.sqlite
# ✅ Ground Truth SQL: SELECT LOCATION FROM gas_station ORDER BY open_year
# ✨ Predicted SQL: SELECT count(*) FROM products WHERE product_type_code = "F"
# ✅ SQL execution matched.
# Sample 33/960
# 🔸 Question: أي عميل قام بعملية دفع واحدة على الأقل قد أنفق أقل مبلغ؟ قم بتقديم الاسم الأول والاسم الأخير، والمعرف.
# 📁 DB: sakila_1.sqlite
# ✅ Ground Truth SQL: SELECT sum(amount) FROM payment
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 34/960
# 🔸 Question: [Question] قائمة اسم نموذج الأجهزة واسم الشركة للهاتف الذي يكون نوع وضع الشاشة الخاص به "الرسومات".
# 📁 DB: phone_1.sqlite
# ✅ Ground Truth SQL: SELECT T2.Hardware_Model_name ,  T2.Company_name FROM screen_mode AS T1 JOIN phone AS T2 ON T1.Graphics_mode = T2.screen_mode WHERE T1.Type  =  "Graphics";
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 35/960
# 🔸 Question: أظهر هويات جميع الطلاب الذكور الذين لا يلعبون كرة القدم.
# 📁 DB: game_1.sqlite
# ✅ Ground Truth SQL: SELECT StuID FROM Student WHERE sex  =  'F' INTERSECT SELECT StuID FROM Sportsinfo WHERE sportname  =  "Football"
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id = T2.staff_id GROUP BY T1.staff_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 36/960
# 🔸 Question: كم عدد ألعاب الفيديو التي لديك؟
# 📁 DB: game_1.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM Video_games
# ✨ Predicted SQL: SELECT T1.name FROM film AS T1 JOIN film AS T2 ON T1.film_id = T2.film_id WHERE T1.film_id = T2.film_id
# ✅ SQL execution matched.
# Sample 37/960
# 🔸 Question: "ابحث عن رمز قناة الاتصال الذي تم استخدامه من قبل العميل بالاسم 'Tillman Ernser'."
# 📁 DB: customers_and_addresses.sqlite
# ✅ Ground Truth SQL: SELECT channel_code FROM customer_contact_channels GROUP BY channel_code HAVING count(customer_id)  <  5
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name FROM
# ✅ SQL execution matched.
# Sample 38/960
# 🔸 Question: عرض جميع أسماء المتاجر لمجموعات ورش العمل المسرحية.
# 📁 DB: cre_Drama_Workshop_Groups.sqlite
# ✅ Ground Truth SQL: SELECT Customer_Phone ,  Customer_Email_Address FROM CUSTOMERS WHERE Customer_Name  =  "Harold"
# ✨ Predicted SQL: SELECT T1.name FROM manufacturers AS T1 JOIN manufacturers AS T2 ON T1.product_id = T2.product_id WHERE T1.product_id = T2.product_id GROUP BY T1.product_id ORDER BY T1.product_id DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 39/960
# 🔸 Question: كم عدد الأعضاء؟
# 📁 DB: network_2.sqlite
# ✅ Ground Truth SQL: SELECT DISTINCT T4.name FROM PersonFriend AS T1 JOIN Person AS T2 ON T1.name  =  T2.name JOIN PersonFriend AS T3 ON T1.friend  =  T3.name JOIN PersonFriend AS T4 ON T3.friend  =  T4.name WHERE T2.name  =  'Alice' AND T4.name != 'Alice'
# ✨ Predicted SQL: SELECT count(*) FROM player
# ✅ SQL execution matched.
# Sample 40/960
# 🔸 Question: ما هي جميع المعلومات حول ملاحظات التقييم مرتبة حسب التاريخ بترتيب تصاعدي؟
# 📁 DB: behavior_monitoring.sqlite
# ✅ Ground Truth SQL: SELECT first_name FROM Teachers WHERE email_address LIKE '%man%'
# ✨ Predicted SQL: SELECT count(*) FROM exhibition WHERE exhibition_id = 'Spring'
# ✅ SQL execution matched.
# Sample 41/960
# 🔸 Question: [Question] أظهر معرف الطالب لجميع الطلاب الذكور.
# 📁 DB: allergy_1.sqlite
# ✅ Ground Truth SQL: SELECT StuID FROM Student WHERE Sex  =  'M'
# ✨ Predicted SQL: SELECT T1.name FROM Employees AS T1 JOIN Customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id = T2.customer_id GROUP BY T1.customer_id
# ✅ SQL execution matched.
# Sample 42/960
# 🔸 Question: ما هو أعلى وأقل مبلغ للتسوية في السجل؟
# 📁 DB: insurance_fnol.sqlite
# ✅ Ground Truth SQL: SELECT max(settlement_amount) ,  min(settlement_amount) FROM settlements
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name FROM
# ✅ SQL execution matched.
# Sample 43/960
# 🔸 Question: ما هي جميع الموظفين بدون رقم قسم؟
# 📁 DB: hr_1.sqlite
# ✅ Ground Truth SQL: SELECT * FROM employees WHERE department_id  =  "null"
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name FROM authors AS T1 JOIN authors AS T2 ON T1.name = T2.name GROUP BY T1.name ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 44/960
# 🔸 Question: [Question] من هم اللاعبون من إندونيسيا؟
# 📁 DB: match_season.sqlite
# ✅ Ground Truth SQL: SELECT T2.Player FROM country AS T1 JOIN match_season AS T2 ON T1.Country_id  =  T2.Country WHERE T1.Country_name  =  "Indonesia"
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name FROM authors AS T1 JOIN authors AS T2 ON T1.name = T2.name GROUP BY T1.name ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 45/960
# 🔸 Question: أي مدرسة لديها أقل عدد من الأساتذة؟
# 📁 DB: college_1.sqlite
# ✅ Ground Truth SQL: SELECT T1.school_code FROM department AS T1 JOIN professor AS T2 ON T1.dept_code  =  T2.dept_code GROUP BY T1.school_code ORDER BY count(*) LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 46/960
# 🔸 Question: "في شهر فبراير، أي مدينة تسجل أعلى درجة حرارة؟"
# 📁 DB: city_record.sqlite
# ✅ Ground Truth SQL: SELECT T1.city FROM city AS T1 JOIN temperature AS T2 ON T1.city_id  =  T2.city_id ORDER BY T2.Feb DESC LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 47/960
# 🔸 Question: ما هو اسم والمتوسط لمعدل النجاح للقسم الذي لديه أعلى متوسط لمعدل النجاح؟
# 📁 DB: college_1.sqlite
# ✅ Ground Truth SQL: SELECT max(stu_gpa) ,  avg(stu_gpa) ,  min(stu_gpa) ,  dept_code FROM student GROUP BY dept_code
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 48/960
# 🔸 Question: اعرض جميع أسماء الكنائس التي استضافت حفل زفاف على الأقل.
# 📁 DB: wedding.sqlite
# ✅ Ground Truth SQL: SELECT T1.name FROM church AS T1 JOIN wedding AS T2 ON T1.church_id  =  T2.church_id GROUP BY T1.church_id HAVING count(*)  >=  2
# ✨ Predicted SQL: SELECT T1.name FROM exhibition AS T1 JOIN exhibition AS T2 ON T1.exhibition_id = T2.exhibition_id WHERE T1.exhibition_id = T2.exhibition_id WHERE T1.exhibition_id = T2.exhibition_id = T2.exhibition_id WHERE T1.exhibition_id = T2.exhibition_id = T2.exhibition_id WHERE T1.exhibition_id = T2.exhibition_id = T2.exhibition_id WHERE T1.exhibition_id = T2.exhibition_id = T2.
# ✅ SQL execution matched.
# Sample 49/960
# 🔸 Question: أي رمز حالة هو الأكثر شيوعًا بين جميع الحجوزات؟
# 📁 DB: cre_Drama_Workshop_Groups.sqlite
# ✅ Ground Truth SQL: SELECT Status_Code FROM BOOKINGS GROUP BY Status_Code ORDER BY count(*) DESC LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM Employees AS T1 JOIN Customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 50/960
# 🔸 Question: بالنسبة لكل منتج يواجه مشاكل، قم بعرض عدد المشاكل ومعرّف المنتج.
# 📁 DB: tracking_software_problems.sqlite
# ✅ Ground Truth SQL: SELECT count(*) ,  T2.product_id FROM problems AS T1 JOIN product AS T2 ON T1.product_id = T2.product_id GROUP BY T2.product_id
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 51/960
# 🔸 Question: اعثر على عدد الأعضاء الذين يعيشون في كل عنوان.
# 📁 DB: coffee_shop.sqlite
# ✅ Ground Truth SQL: SELECT count(*) ,  address FROM member GROUP BY address
# ✨ Predicted SQL: SELECT count(*) FROM Employees
# ✅ SQL execution matched.
# Sample 52/960
# 🔸 Question: ما هي أسماء النواب وتواريخ الانتخابات التي شاركوا فيها؟
# 📁 DB: election_representative.sqlite
# ✅ Ground Truth SQL: SELECT T2.Name ,  T1.Date FROM election AS T1 JOIN representative AS T2 ON T1.Representative_ID  =  T2.Representative_ID
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 53/960
# 🔸 Question: ما هي أسماء الحلبات التي تنتمي إلى المملكة المتحدة أو ماليزيا؟
# 📁 DB: formula_1.sqlite
# ✅ Ground Truth SQL: SELECT name FROM circuits WHERE country = "UK" OR country = "Malaysia"
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id = T2.
# ✅ SQL execution matched.
# Sample 54/960
# 🔸 Question: "أي قناة اتصال تم استخدامها من قبل العميل بالاسم 'Tillman Ernser'؟"
# 📁 DB: customers_and_addresses.sqlite
# ✅ Ground Truth SQL: SELECT country FROM addresses GROUP BY country HAVING count(address_id)  >  4
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.employeeid = T2.employeeid WHERE T1.employeeid = T2.employeeid WHERE T1.employeeid = "Employee"
# ✅ SQL execution matched.
# Sample 55/960
# 🔸 Question: ما هو المبلغ المتوسط والإجمالي للمعاملات؟
# 📁 DB: customers_card_transactions.sqlite
# ✅ Ground Truth SQL: SELECT avg(transaction_amount) ,  sum(transaction_amount) FROM Financial_transactions
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name FROM
# ✅ SQL execution matched.
# Sample 56/960
# 🔸 Question: ما هي عناوين الأوراق التي نُشرت بواسطة "جيريمي جيبونز"؟
# 📁 DB: icfp_1.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM papers
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.employeeid = T2.employeeid WHERE T1.employeeid = T2.employeeid WHERE T1.employeeid = "Aircraft"
# ✅ SQL execution matched.
# Sample 57/960
# 🔸 Question: ما هو الولاية التي تحتوي على أكبر عدد من العملاء؟
# 📁 DB: loan_1.sqlite
# ✅ Ground Truth SQL: SELECT T1.cust_name FROM customer AS T1 JOIN loan AS T2 ON T1.cust_id  =  T2.cust_id GROUP BY T1.cust_name ORDER BY sum(T2.amount) DESC LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 58/960
# 🔸 Question: [Question] ما هي المسافة والسعر المتوسطين للرحلات من لوس أنجلوس؟
# 📁 DB: flight_1.sqlite
# ✅ Ground Truth SQL: SELECT avg(distance) ,  avg(price) FROM Flight WHERE origin  =  "Los Angeles"
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 59/960
# 🔸 Question: سرد أسماء جميع الطيارين بترتيب تنازلي حسب العمر.
# 📁 DB: aircraft.sqlite
# ✅ Ground Truth SQL: SELECT T1.Aircraft ,  COUNT(*) FROM aircraft AS T1 JOIN MATCH AS T2 ON T1.Aircraft_ID  =  T2.Winning_Aircraft GROUP BY T2.Winning_Aircraft
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 60/960
# 🔸 Question: ما هو الاسم الأول والأخير لأكبر سناً من بين الموظفين؟
# 📁 DB: college_1.sqlite
# ✅ Ground Truth SQL: SELECT T2.emp_fname ,  T1.prof_office FROM professor AS T1 JOIN employee AS T2 ON T1.emp_num  =  T2.emp_num ORDER BY T2.emp_fname
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.employeeid = T2.employeeid WHERE T1.employeeid = T2.employeeid
# ✅ SQL execution matched.
# Sample 61/960
# 🔸 Question: ما هو إجمالي الوحدات الدراسية التي تقدمها كل قسم؟
# 📁 DB: college_1.sqlite
# ✅ Ground Truth SQL: SELECT count(*) ,  crs_code FROM CLASS GROUP BY crs_code
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id GROUP BY T1.staff_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 62/960
# 🔸 Question: ما هو اسم المستوى لأرخص فهرس (بالدولار الأمريكي)؟
# 📁 DB: product_catalog.sqlite
# ✅ Ground Truth SQL: SELECT t2.catalog_level_name FROM catalog_contents AS t1 JOIN catalog_structure AS t2 ON t1.catalog_level_number  =  t2.catalog_level_number ORDER BY t1.price_in_dollars LIMIT 1
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 63/960
# 🔸 Question: ما هي الأسماء الأولى ومواقع المكاتب لجميع المحاضرين الذين قاموا بتدريس دورة معينة؟
# 📁 DB: college_1.sqlite
# ✅ Ground Truth SQL: SELECT T2.emp_fname ,  T4.prof_office ,  T3.crs_description FROM CLASS AS T1 JOIN employee AS T2 ON T1.prof_num  =  T2.emp_num JOIN course AS T3 ON T1.crs_code  =  T3.crs_code JOIN professor AS T4 ON T2.emp_num  =  T4.emp_num
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 64/960
# 🔸 Question: ما هي رموز المواقع وتواريخ البدء والانتهاء في تلك المواقع لكل وثيقة؟
# 📁 DB: cre_Doc_Tracking_DB.sqlite
# ✅ Ground Truth SQL: SELECT location_code ,  date_in_location_from ,  date_in_locaton_to FROM Document_locations
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 65/960
# 🔸 Question: ما هي تواريخ الانتهاء لجميع الاختبارات التي حققت نتيجتها "رسوب"؟
# 📁 DB: e_learning.sqlite
# ✅ Ground Truth SQL: SELECT T1.date_of_enrolment FROM Student_Course_Enrolment AS T1 JOIN Student_Tests_Taken AS T2 ON T1.registration_id  =  T2.registration_id WHERE T2.test_result  =  "Pass"
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name FROM
# ✅ SQL execution matched.
# Sample 66/960
# 🔸 Question: ابحث عن أسماء الممرضات اللاتي يقدمن الرعاية للمرضى الذين يخضعون لعلاج؟
# 📁 DB: hospital_1.sqlite
# ✅ Ground Truth SQL: SELECT DISTINCT name FROM nurse ORDER BY name
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name FROM Employees AS T1 JOIN Customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY T1.customer_id DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 67/960
# 🔸 Question: [Question] ابحث عن عدد الهواتف لكل نوع من أنواع التصديق.
# 📁 DB: phone_1.sqlite
# ✅ Ground Truth SQL: SELECT Accreditation_type ,  count(*) FROM phone GROUP BY Accreditation_type
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 68/960
# 🔸 Question: ما هي أسماء الأشخاص الذين لديهم صديق واحد فقط؟
# 📁 DB: network_2.sqlite
# ✅ Ground Truth SQL: SELECT name FROM PersonFriend GROUP BY name HAVING count(*)  =  1
# ✨ Predicted SQL: SELECT T1.name FROM Employees AS T1 JOIN Customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 69/960
# 🔸 Question: ما هو وصف نوع المنظمة التي يتم تفاصيلها كـ 'quo'؟
# 📁 DB: tracking_grants_for_research.sqlite
# ✅ Ground Truth SQL: SELECT T1.organisation_type_description FROM organisation_Types AS T1 JOIN Organisations AS T2 ON T1.organisation_type  =  T2.organisation_type WHERE T2.organisation_details  =  'quo'
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name FROM
# ✅ SQL execution matched.
# Sample 70/960
# 🔸 Question: "ما هي أسماء الكاميرات التي التقطت صوراً لمعظم الجبال؟"
# 📁 DB: mountain_photos.sqlite
# ✅ Ground Truth SQL: SELECT T1.id ,  T1.name FROM mountain AS T1 JOIN photos AS T2 ON T1.id  =  T2.mountain_id GROUP BY T1.id HAVING count(*)  >=  2
# ✨ Predicted SQL: SELECT T1.title FROM film AS T1 JOIN film AS T2 ON T1.film_id = T2.film_id WHERE T1.film_id = T2.film_id GROUP BY T1.film_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 71/960
# 🔸 Question: ما هي الأسماء الكاملة للعملاء ذوي اسم الحساب 900؟
# 📁 DB: customers_and_invoices.sqlite
# ✅ Ground Truth SQL: SELECT T2.customer_first_name ,  T2.customer_last_name FROM Accounts AS T1 JOIN Customers AS T2 ON T1.customer_id  =  T2.customer_id WHERE T1.account_name  =  "900"
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name FROM Employees AS T1 JOIN Customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY T1.customer_id DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 72/960
# 🔸 Question: ما هي أسماء الصحفيين مرتبة بترتيب تصاعدي حسب سنوات الخبرة؟
# 📁 DB: news_report.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM journalist
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 73/960
# 🔸 Question: العثور على أسماء العملاء الذين إما لديهم سياسة نائب أو سياسة موحدة.
# 📁 DB: insurance_and_eClaims.sqlite
# ✅ Ground Truth SQL: SELECT DISTINCT t2.customer_details FROM policies AS t1 JOIN customers AS t2 ON t1.customer_id  =  t2.customer_id WHERE t1.policy_type_code  =  "Deputy" OR t1.policy_type_code  =  "Uniform"
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id GROUP BY T1.staff_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 74/960
# 🔸 Question: ابحث عن المتوسط ​​لعدد المتابعين للمستخدمين الذين لا يمتلكون أي تغريدة.
# 📁 DB: twitter_1.sqlite
# ✅ Ground Truth SQL: SELECT avg(followers) FROM user_profiles WHERE UID NOT IN (SELECT UID FROM tweets)
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 75/960
# 🔸 Question: ما هي مدة أطول وأقصر مسارات البوب بالمللي ثانية؟
# 📁 DB: chinook_1.sqlite
# ✅ Ground Truth SQL: SELECT max(Milliseconds) ,  min(Milliseconds) FROM GENRE AS T1 JOIN TRACK AS T2 ON T1.GenreId  =  T2.GenreId WHERE T1.Name  =  "Pop"
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name FROM authors AS T1 JOIN authors AS T2 ON T1.name = T2.name GROUP BY T1.name ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 76/960
# 🔸 Question: ابحث عن أسماء الشركات التي لا تصنع محركات أقراص دي في دي.
# 📁 DB: manufactory_1.sqlite
# ✅ Ground Truth SQL: SELECT count(DISTINCT name) FROM products WHERE name NOT IN (SELECT T1.name FROM products AS T1 JOIN manufacturers AS T2 ON T1.Manufacturer  =  T2.code WHERE T2.name  =  'Sony')
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 77/960
# 🔸 Question: إلى أي عنوان تم إرسال المستند ذو الهوية 4؟
# 📁 DB: cre_Doc_Control_Systems.sqlite
# ✅ Ground Truth SQL: SELECT Addresses.address_details FROM Addresses JOIN Documents_Mailed ON Documents_Mailed.mailed_to_address_id = Addresses.address_id WHERE document_id = 4;
# ✨ Predicted SQL: SELECT count(*) FROM film
# ✅ SQL execution matched.
# Sample 78/960
# 🔸 Question: ما هي التفاصيل للمشاريع التي تم إطلاقها بواسطة المنظمة التي لديها أكبر عدد من المشاريع؟
# 📁 DB: tracking_grants_for_research.sqlite
# ✅ Ground Truth SQL: SELECT project_details FROM Projects WHERE organisation_id IN ( SELECT organisation_id FROM Projects GROUP BY organisation_id ORDER BY count(*) DESC LIMIT 1 )
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id GROUP BY T1.staff_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 79/960
# 🔸 Question: ما هو متوسط الرسوم لحرم جامعة كاليفورنيا الحكومية في عام ٢٠٠٥؟
# 📁 DB: csu_1.sqlite
# ✅ Ground Truth SQL: SELECT avg(campusfee) FROM csu_fees WHERE YEAR  =  2005
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 80/960
# 🔸 Question: ما هي الجنسية والمهنة للاعبين؟
# 📁 DB: riding_club.sqlite
# ✅ Ground Truth SQL: SELECT Gender ,  Occupation FROM player
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 81/960
# 🔸 Question: ما هو الإيراد الإجمالي للشركات التي يكون إيرادها أكبر من أقل إيراد لأي شركة مصنعة في أوستن؟
# 📁 DB: manufactory_1.sqlite
# ✅ Ground Truth SQL: SELECT sum(revenue) FROM manufacturers WHERE revenue  >  (SELECT min(revenue) FROM manufacturers WHERE headquarter  =  'Austin')
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 82/960
# 🔸 Question: لكل موقع، ما هو الحد الأقصى لعدد الساعات للطلاب الذين قضوا أكثر من 1000 ساعة في التدريب؟
# 📁 DB: soccer_2.sqlite
# ✅ Ground Truth SQL: SELECT max(T1.HS) ,  pPos FROM player AS T1 JOIN tryout AS T2 ON T1.pID  =  T2.pID WHERE T1.HS  >  1000 GROUP BY T2.pPos
# ✨ Predicted SQL: SELECT count(*) FROM employees WHERE salary > 1000
# ✅ SQL execution matched.
# Sample 83/960
# 🔸 Question: لكل معرف مشروع، كم عدد المهام الموجودة؟
# 📁 DB: tracking_grants_for_research.sqlite
# ✅ Ground Truth SQL: SELECT count(*) ,  T1.project_details FROM Projects AS T1 JOIN Tasks AS T2 ON T1.project_id  =  T2.project_id GROUP BY T1.project_id
# ✨ Predicted SQL: SELECT count(*) FROM products
# ✅ SQL execution matched.
# Sample 84/960
# 🔸 Question: مرتبة أسماء الشركات بترتيب تنازلي حسب قيمة السوق للشركة.
# 📁 DB: company_office.sqlite
# ✅ Ground Truth SQL: SELECT name FROM Companies ORDER BY Market_Value_billion DESC
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 85/960
# 🔸 Question: ما هي أسماء الأغاني التي يكون تقييمها أقل من تقييم جميع الأغاني باللغة الإنجليزية؟
# 📁 DB: music_1.sqlite
# ✅ Ground Truth SQL: SELECT T1.country FROM artist AS T1 JOIN song AS T2 ON T1.artist_name  =  T2.artist_name GROUP BY T2.artist_name ORDER BY count(*) LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 86/960
# 🔸 Question: من أي مصدر استطلاع يأتي أعلى معدل معارضة؟
# 📁 DB: candidate_poll.sqlite
# ✅ Ground Truth SQL: SELECT Support_rate ,  Consider_rate ,  Oppose_rate FROM candidate ORDER BY unsure_rate
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 87/960
# 🔸 Question: سجل أقصى نقاط لفريق بوسطن ريد ستوكينغز عندما فاز الفريق في مرحلة ما بعد الموسم؟
# 📁 DB: baseball_1.sqlite
# ✅ Ground Truth SQL: SELECT name_first ,  name_last FROM player WHERE weight  >  220 OR height  <  75
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 88/960
# 🔸 Question: "أي برنامج يتم بثه بشكل أكثر تواترًا؟ أعطني اسم البرنامج."
# 📁 DB: program_share.sqlite
# ✅ Ground Truth SQL: SELECT t1.name FROM program AS t1 JOIN broadcast AS t2 ON t1.program_id  =  t2.program_id GROUP BY t2.program_id ORDER BY count(*) DESC LIMIT 1
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 89/960
# 🔸 Question: ما هي أحجام الملفات والتنسيقات لجميع الأغاني التي تحتوي على دقة أقل من 800؟
# 📁 DB: music_1.sqlite
# ✅ Ground Truth SQL: SELECT DISTINCT T1.file_size ,  T1.formats FROM files AS T1 JOIN song AS T2 ON T1.f_id  =  T2.f_id WHERE T2.resolution  <  800
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id
# ✅ SQL execution matched.
# Sample 90/960
# 🔸 Question: [Question] سرد أسماء والمواقع التي يمكن للإنزيمات أن تؤثر فيها.
# 📁 DB: medicine_enzyme_interaction.sqlite
# ✅ Ground Truth SQL: SELECT name ,  LOCATION FROM enzyme
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name FROM Employees AS T1 JOIN Customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 91/960
# 🔸 Question: اعرض العام الذي تم فيه فتح ما لا يقل عن كنيستين.
# 📁 DB: wedding.sqlite
# ✅ Ground Truth SQL: SELECT open_date FROM church GROUP BY open_date HAVING count(*)  >=  2
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.employeeid = T2.employeeid WHERE T1.employeeid = T2.employeeid = T2.employeeid WHERE T1.employeeid = T2.employeeid
# ✅ SQL execution matched.
# Sample 92/960
# 🔸 Question: من هم أعضاء "Bootup Baltimore" الذين يدرسون "600"؟ أعطني أسمائهم الأولى وأسمائهم الأخيرة.
# 📁 DB: club_1.sqlite
# ✅ Ground Truth SQL: SELECT t3.fname ,  t3.lname FROM club AS t1 JOIN member_of_club AS t2 ON t1.clubid  =  t2.clubid JOIN student AS t3 ON t2.stuid  =  t3.stuid WHERE t1.clubname  =  "Bootup Baltimore" AND t3.major  =  "600"
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name FROM
# ✅ SQL execution matched.
# Sample 93/960
# 🔸 Question: ما هو متوسط تقييم الأغاني لكل لغة؟
# 📁 DB: music_1.sqlite
# ✅ Ground Truth SQL: SELECT avg(rating) ,  languages FROM song GROUP BY languages
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name FROM authors AS T1 JOIN authors AS T2 ON T1.name = T2.name GROUP BY T1.name ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 94/960
# 🔸 Question: أعطني أقصى درجة حرارة منخفضة ومتوسط هطول الأمطار في محطة أمرشام.
# 📁 DB: station_weather.sqlite
# ✅ Ground Truth SQL: SELECT avg(high_temperature) ,  day_of_week FROM weekly_weather GROUP BY day_of_week
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 95/960
# 🔸 Question: ما هي رموز الأدوار المختلفة للمستخدمين، وكم عدد المستخدمين في كل منها؟
# 📁 DB: document_management.sqlite
# ✅ Ground Truth SQL: SELECT count(*) ,  role_code FROM users GROUP BY role_code
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 96/960
# 🔸 Question: كم معلما يدرس الطالب المسمى CHRISSY NABOZNY؟
# 📁 DB: student_1.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM list AS T1 JOIN teachers AS T2 ON T1.classroom  =  T2.classroom WHERE T2.firstname  =  "TARRING" AND T2.lastname  =  "LEIA"
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 97/960
# 🔸 Question: ما هي الاسم الأول والاسم الأخير لجميع الطلاب الذين يلعبون كرة القدم أو لاكروس؟
# 📁 DB: game_1.sqlite
# ✅ Ground Truth SQL: SELECT T2.lname ,  T2.fname FROM SportsInfo AS T1 JOIN Student AS T2 ON T1.StuID  =  T2.StuID WHERE T1.SportName  =  "Football" OR T1.SportName  =  "Lacrosse"
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id GROUP BY T1.staff_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 98/960
# 🔸 Question: ما هي عناوين البريد الإلكتروني للموظفين الذين يمتلكون قيمة "null" للعمولة، ويتقاضون رواتب في النطاق بين 7000 و 12000، ويعملون في القسم رقم 50؟
# 📁 DB: hr_1.sqlite
# ✅ Ground Truth SQL: SELECT email FROM employees WHERE commission_pct  =  "null" AND salary BETWEEN 7000 AND 12000 AND department_id = 50
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 99/960
# 🔸 Question: عدد الغرف في Lamberton بسعة أقل من 50.
# 📁 DB: college_2.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM classroom WHERE building  =  'Lamberton' AND capacity  <  50
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id GROUP BY T1.customer_id
# ✅ SQL execution matched.
# Sample 100/960
# 🔸 Question: "ما هي أسماء المطارات التي ليست في بلد 'آيسلندا'؟"
# 📁 DB: flight_company.sqlite
# ✅ Ground Truth SQL: SELECT T1.name ,  T1.type FROM operate_company AS T1 JOIN flight AS t2 ON T1.id  =  T2.company_id
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.id = T2.id JOIN employees AS T2 ON T1.id = T2.id JOIN employees AS T2 ON T1.id = T2.id WHERE T1.id = T2.id GROUP BY T1.id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 101/960
# 🔸 Question: كم عدد الأقسام التي يحتوي عليها كل مقرر؟
# 📁 DB: college_1.sqlite
# ✅ Ground Truth SQL: SELECT count(*) ,  crs_code FROM CLASS GROUP BY crs_code
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id GROUP BY T1.staff_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 102/960
# 🔸 Question: ما هو عدد الأغاني التي تستمر لمدة تقريبية 4 دقائق؟
# 📁 DB: music_1.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM files WHERE duration LIKE "4:%"
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 103/960
# 🔸 Question: ما هو متوسط الطول والوزن بين الذكور (الجنس هو M)؟
# 📁 DB: candidate_poll.sqlite
# ✅ Ground Truth SQL: SELECT avg(height) ,  avg(weight) FROM people WHERE sex  =  'M'
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name FROM
# ✅ SQL execution matched.
# Sample 104/960
# 🔸 Question: [Question] أظهر جميع اللغات الأم الرسمية التي تحتوي على كلمة "إنجليزية".
# 📁 DB: match_season.sqlite
# ✅ Ground Truth SQL: SELECT Official_native_language FROM country WHERE Official_native_language LIKE "%English%"
# ...
# ✅ SQL execution matched.
# Sample 927/960
# 🔸 Question: [Question] ما هي الأسماء والمسافات لجميع الطائرات؟
# 📁 DB: flight_1.sqlite
# ✅ Ground Truth SQL: SELECT name ,  distance FROM Aircraft
# ✨ Predicted SQL: SELECT T1.name FROM Employees AS T1 JOIN Customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = "Employee"
# ✅ SQL execution matched.
# Sample 928/960
# 🔸 Question: قائمة أسماء الأعمال الفنية التي نوعها ليس "برنامج مواهب".
# 📁 DB: entertainment_awards.sqlite
# ✅ Ground Truth SQL: SELECT Name FROM artwork ORDER BY Name ASC
# ✨ Predicted SQL: SELECT T1.name FROM authors AS T1 JOIN authors AS T2 ON T1.id = T2.id JOIN authors AS T2 ON T1.id = T2.id JOIN authors AS T2 ON T1.id = T2.id JOIN authors AS T2 ON T1.id GROUP BY T1.id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 929/960
# 🔸 Question: [Question] ما هي الأعمار المتوسطة للطلاب الذكور والإناث؟
# 📁 DB: allergy_1.sqlite
# ✅ Ground Truth SQL: SELECT avg(age) ,  sex FROM Student GROUP BY sex
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.employee_id = T2.employee_id WHERE T1.employee_id = T2.employee_id = T2.employee_id GROUP BY T1.employee_id ORDER BY T1.employee_id DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 930/960
# 🔸 Question: ارجع بتاريخ الانتهاء لجميع الاختبارات التي حققت نتيجتها "رسوب".
# 📁 DB: e_learning.sqlite
# ✅ Ground Truth SQL: SELECT T1.date_of_completion FROM Student_Course_Enrolment AS T1 JOIN Student_Tests_Taken AS T2 ON T1.registration_id  =  T2.registration_id WHERE T2.test_result  =  "Fail"
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name FROM Employees AS T1 JOIN Customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 931/960
# 🔸 Question: ما هي الهويات، والأسماء، وتواريخ الافتتاح، والتفاصيل الأخرى للحسابات المتعلقة بالعميل الذي لديه الاسم الأول "ميغان"؟
# 📁 DB: customers_and_invoices.sqlite
# ✅ Ground Truth SQL: SELECT T1.account_id ,  T1.date_account_opened ,  T1.account_name ,  T1.other_account_details FROM Accounts AS T1 JOIN Customers AS T2 ON T1.customer_id  =  T2.customer_id WHERE T2.customer_first_name  =  'Meaghan'
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 932/960
# 🔸 Question: "ما هي أنواع السفن التي تحمل كل من السفن ذات الأعلام البنمية والمالطية؟"
# 📁 DB: ship_1.sqlite
# ✅ Ground Truth SQL: SELECT TYPE FROM ship WHERE flag  =  'Panama' INTERSECT SELECT TYPE FROM ship WHERE flag  =  'Malta'
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 933/960
# 🔸 Question: كم عدد الطلاب في كل قسم؟
# 📁 DB: college_1.sqlite
# ✅ Ground Truth SQL: SELECT count(*) ,  dept_code FROM student GROUP BY dept_code
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name FROM authors AS T1 JOIN authors AS T2 ON T1.name = T2.name GROUP BY T1.name ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 934/960
# 🔸 Question: ما هو رمز اللون والوصف للمنتج بالاسم "الشبت"؟
# 📁 DB: products_gen_characteristics.sqlite
# ✅ Ground Truth SQL: SELECT t2.color_description FROM products AS t1 JOIN ref_colors AS t2 ON t1.color_code  =  t2.color_code WHERE t1.product_name  =  "catnip"
# ✨ Predicted SQL: SELECT count(*) FROM player
# ✅ SQL execution matched.
# Sample 935/960
# 🔸 Question: إرجاع المتوسط الإجمالي للمبلغ المشترى والقيمة المشتراة الإجمالية للمورد الذي يورد أكبر عدد من المنتجات.
# 📁 DB: department_store.sqlite
# ✅ Ground Truth SQL: SELECT avg(total_amount_purchased) ,  avg(total_value_purchased) FROM Product_Suppliers WHERE supplier_id  =  (SELECT supplier_id FROM Product_Suppliers GROUP BY supplier_id ORDER BY count(*) DESC LIMIT 1)
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 936/960
# 🔸 Question: كم عدد الأصول التي يمكن استخدام كل جزء فيها؟ قم بسرد اسم الجزء والعدد.
# 📁 DB: assets_maintenance.sqlite
# ✅ Ground Truth SQL: SELECT T1.fault_short_name ,  T3.skill_description FROM Part_Faults AS T1 JOIN Skills_Required_To_Fix AS T2 ON T1.part_fault_id  =  T2.part_fault_id JOIN Skills AS T3 ON T2.skill_id  =  T3.skill_id
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.id = T2.id JOIN employees AS T2 ON T1.id = T2.id WHERE T1.id = T2.id GROUP BY T1.id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 937/960
# 🔸 Question: ما هي أنواع وجنسيات كل سفينة؟
# 📁 DB: ship_mission.sqlite
# ✅ Ground Truth SQL: SELECT TYPE ,  Nationality FROM ship
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 938/960
# 🔸 Question: اذكر عناوين جميع مؤلفي أو معلمي الدورات.
# 📁 DB: e_learning.sqlite
# ✅ Ground Truth SQL: SELECT address_line_1 FROM Course_Authors_and_Tutors WHERE personal_name	 =  "Cathrine"
# ✨ Predicted SQL: SELECT T1.name FROM Employees AS T1 JOIN Customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 939/960
# 🔸 Question: أي سنة كان بها أكبر عدد من الدورات؟
# 📁 DB: college_2.sqlite
# ✅ Ground Truth SQL: SELECT YEAR FROM SECTION GROUP BY YEAR ORDER BY count(*) DESC LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id
# ✅ SQL execution matched.
# Sample 940/960
# 🔸 Question: ما هي الناشرين المتميزين للإصدارات ذات السعر الأعلى من 5000000؟
# 📁 DB: book_2.sqlite
# ✅ Ground Truth SQL: SELECT DISTINCT Publisher FROM publication WHERE Price  >  5000000
# ✨ Predicted SQL: SELECT count(*) FROM Customers
# ✅ SQL execution matched.
# Sample 941/960
# 🔸 Question: كم عدد موظفي المشروع الذين عملوا كقادة أو بدأوا العمل قبل '1989-04-24 23:51:54'؟
# 📁 DB: tracking_grants_for_research.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM Project_outcomes WHERE outcome_code  =  'Patent'
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 942/960
# 🔸 Question: ما هي معرّف الوظيفة وتاريخ التوظيف لتلك الموظفين الذين تم توظيفهم بين الخامس من نوفمبر، 2007 والخامس من يوليو، 2009؟
# 📁 DB: hr_1.sqlite
# ✅ Ground Truth SQL: SELECT first_name ,  last_name ,  salary FROM employees WHERE first_name LIKE '%m'
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 943/960
# 🔸 Question: عدد المدن في ولاية كولورادو هو كم؟
# 📁 DB: e_government.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM addresses WHERE state_province_county  =  "Colorado"
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name FROM authors AS T1 JOIN authors AS T2 ON T1.name = T2.name GROUP BY T1.name ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 944/960
# 🔸 Question: ما هو تاريخ البريد للمستند ذو الهوية 7؟
# 📁 DB: cre_Doc_Control_Systems.sqlite
# ✅ Ground Truth SQL: SELECT mailing_date FROM Documents_Mailed WHERE document_id = 7;
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 945/960
# 🔸 Question: اختر أسماء الشركات المصنعة التي يكون متوسط سعر منتجاتها أعلى من أو يساوي 150 دولارًا.
# 📁 DB: manufactory_1.sqlite
# ✅ Ground Truth SQL: SELECT avg(T1.Price) ,  T2.name FROM products AS T1 JOIN Manufacturers AS T2 ON T1.manufacturer  =  T2.code GROUP BY T2.name
# ✨ Predicted SQL: SELECT count(*) FROM products WHERE product_type_code = 150
# ✅ SQL execution matched.
# Sample 946/960
# 🔸 Question: قائمة الوصف والرمز وعدد الخدمات لكل نوع من أنواع الخدمات.
# 📁 DB: cre_Drama_Workshop_Groups.sqlite
# ✅ Ground Truth SQL: SELECT T1.Service_Type_Description ,  T2.Service_Type_Code ,  COUNT(*) FROM Ref_Service_Types AS T1 JOIN Services AS T2 ON T1.Service_Type_Code  =  T2.Service_Type_Code GROUP BY T2.Service_Type_Code
# ✨ Predicted SQL: SELECT count(*) , count(*) , count(*) , count(*) , count(*) FROM products
# ✅ SQL execution matched.
# Sample 947/960
# 🔸 Question: ما هو الرقم التعريفي والسلطة المحلية للمحطة التي تتجاوز كمية الهطول القصوى لديها الـ 50؟
# 📁 DB: station_weather.sqlite
# ✅ Ground Truth SQL: SELECT t2.id ,  t2.local_authority FROM weekly_weather AS t1 JOIN station AS t2 ON t1.station_id  =  t2.id GROUP BY t1.station_id ORDER BY avg(high_temperature) DESC LIMIT 1
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id
# ✅ SQL execution matched.
# Sample 948/960
# 🔸 Question: ما هي الأسماء الأولى للأساتذة من قسم التاريخ الذين لا يدرسون صفًا؟
# 📁 DB: college_1.sqlite
# ✅ Ground Truth SQL: SELECT emp_fname FROM employee WHERE emp_jobcode  =  'PROF' EXCEPT SELECT T1.emp_fname FROM employee AS T1 JOIN CLASS AS T2 ON T1.emp_num  =  T2.prof_num
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.staff_id = T2.staff_id WHERE T1.staff_id = T2.staff_id = T2.staff_id GROUP BY T1.staff_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 949/960
# 🔸 Question: كم عدد عناصر التقويم لدينا؟
# 📁 DB: film_rank.sqlite
# ✅ Ground Truth SQL: SELECT title ,  director FROM film WHERE film_id NOT IN (SELECT film_id FROM film_market_estimation AS T1 JOIN market AS T2 ON T1.market_id  =  T2.Market_ID WHERE country  =  'China')
# ✨ Predicted SQL: SELECT count(*) FROM employees
# ✅ SQL execution matched.
# Sample 950/960
# 🔸 Question: لكل معرّف للسائق الذي شارك في 30 سباقًا على الأكثر، كم عدد السباقات التي شارك فيها؟
# 📁 DB: formula_1.sqlite
# ✅ Ground Truth SQL: SELECT T1.driverid ,  count(*) FROM drivers AS T1 JOIN results AS T2 ON T1.driverid = T2.driverid JOIN races AS T3 ON T2.raceid = T3.raceid GROUP BY T1.driverid HAVING count(*)  <=  30
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name FROM Employees AS T1 JOIN Customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id HAVING count(*) > 30
# ✅ SQL execution matched.
# Sample 951/960
# 🔸 Question: [Translation] ما هي معرفات الرحلات التي استمرت لفترة أطول ومدى مدة استمرارها؟
# 📁 DB: bike_1.sqlite
# ✅ Ground Truth SQL: SELECT id ,  duration FROM trip ORDER BY duration DESC LIMIT 3
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 952/960
# 🔸 Question: اعثر على أسماء العملاء الأخيرة التي ليست لديها مجموع فواتير يتجاوز 20.
# 📁 DB: chinook_1.sqlite
# ✅ Ground Truth SQL: SELECT LastName FROM CUSTOMER EXCEPT SELECT T1.LastName FROM CUSTOMER AS T1 JOIN Invoice AS T2 ON T1.CustomerId  =  T2.CustomerId WHERE T2.total  >  20
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 953/960
# 🔸 Question: ما هو عدد الطلاب الذين يلعبون دور حارس المرمى؟
# 📁 DB: soccer_2.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM tryout WHERE pPos  =  'goalie'
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN employees AS T2 ON T1.employee_id = T2.employee_id WHERE T1.employee_id = T2.employee_id GROUP BY T1.employee_id ORDER BY T1.employee_id DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 954/960
# 🔸 Question: ما هي الأسماء لأعلى ثلاثة فروع بأكبر عدد من العضويات؟
# 📁 DB: shop_membership.sqlite
# ✅ Ground Truth SQL: SELECT name ,  address_road ,  city FROM branch ORDER BY open_year
# ✨ Predicted SQL: SELECT T1.name FROM exhibition AS T1 JOIN film AS T2 ON T1.film_id = T2.film_id WHERE T1.film_id = T2.film_id GROUP BY T1.film_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 955/960
# 🔸 Question: أظهر أقصى وأدنى عدد للأسهم لأنواع المعاملات المختلفة.
# 📁 DB: tracking_share_transactions.sqlite
# ✅ Ground Truth SQL: SELECT transaction_type_code ,  avg(amount_of_transaction) FROM TRANSACTIONS GROUP BY transaction_type_code
# ✨ Predicted SQL: SELECT count(*) FROM exhibition WHERE exhibition_id = 'Spring'
# ✅ SQL execution matched.
# Sample 956/960
# 🔸 Question: "ما هو قائمة أسماء البرامج، مرتبة حسب ترتيب تاريخ الإطلاق؟"
# 📁 DB: program_share.sqlite
# ✅ Ground Truth SQL: SELECT name FROM program ORDER BY launch
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# Sample 957/960
# 🔸 Question: اعثر على الأسماء للحسابات التي يكون رصيدها الجاري أعلى من رصيد الادخار المقابل.
# 📁 DB: small_bank_1.sqlite
# ✅ Ground Truth SQL: SELECT T1.name FROM accounts AS T1 JOIN checking AS T2 ON T1.custid  =  T2.custid JOIN savings AS T3 ON T1.custid  =  T3.custid WHERE T2.balance  >  T3.balance
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name FROM Employees AS T1 JOIN Customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 958/960
# 🔸 Question: قائمة أسماء الأعمال الفنية بترتيب أبجدي تصاعدي.
# 📁 DB: entertainment_awards.sqlite
# ✅ Ground Truth SQL: SELECT count(*) FROM artwork
# ✨ Predicted SQL: SELECT T1.name FROM employees AS T1 JOIN customers AS T2 ON T1.customer_id = T2.customer_id WHERE T1.customer_id = T2.customer_id GROUP BY T1.customer_id ORDER BY count(*) DESC LIMIT 1
# ✅ SQL execution matched.
# Sample 959/960
# 🔸 Question: كم عدد المدارس الموجودة في القسم؟
# 📁 DB: college_1.sqlite
# ✅ Ground Truth SQL: SELECT count(DISTINCT school_code) FROM department
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name FROM exhibition AS T1 JOIN film AS T2 ON T1.film_id = T2.film_id WHERE T1.film_id = T2.film_id WHERE T1.film_id = T2.film_id
# ✅ SQL execution matched.
# Sample 960/960
# 🔸 Question: بالنسبة لأقدم فيلم مدرج، ما هو متوسط التقييم والعنوان؟
# 📁 DB: movie_1.sqlite
# ✅ Ground Truth SQL: SELECT avg(T1.stars) ,  T2.title FROM Rating AS T1 JOIN Movie AS T2 ON T1.mID  =  T2.mID WHERE T2.year  =  (SELECT min(YEAR) FROM Movie)
# ✨ Predicted SQL: SELECT T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name , T1.name ,
# ✅ SQL execution matched.
# ✅ Exact Match Accuracy: 0.0000
# ✅ Execution Accuracy: 1.0000
# ✅ Average BLEU Score: 0.1797
